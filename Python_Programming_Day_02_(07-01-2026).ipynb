# %%
Introduction to Python Programming :

# %%
Understanding the variables in Python :

# %%
a=2

# %%
b=3

# %%
c=a+b

# %%
print(c)

# %%
Rules for declaring the variable name

# %%
Rule No:1 No namespaces while declaring the variable name

# %%
first name = 'Ali'

# %%
print(first name)
# Out:
#   Cell In[5], line 1
#     print(first name)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
The correct way is :

# %%
firstname = 'Ali'

# %%
print(firstname)
# Out:
# Ali

# %%
first_name = "Ali"

# %%
print(first_name)
# Out:
# Ali

# %%
Rule No:2 A variable name should not start with numbers** (Important)

# %%
1name = 'anand'
# Out:
#   Cell In[20], line 1
#     1name = 'anand'
#     ^
# SyntaxError: invalid decimal literal

# %%
The correct way is :

# %%
name1 = 'ajay'

# %%
print(name1)
# Out:
# ajay

# %%
Rule No:3 A variable should not contain special charecters (@,#,$,%,^,&,*,etc,) are specia; charecters

# %%
name@ = 'Amir'

# %%
print(name@)
# Out:
#   Cell In[29], line 1
#     print(name@)
#                ^
# SyntaxError: invalid syntax

# %%
Introduction to Datatypes in Python

# %%
1. String ----> (str)

# %%
2. Numbers (integer) ----> (int)

# %%
3. Lists ----> (list)

# %%
4. Tuples ----> (tuple)

# %%
5. Dictionaries ----> (dict)

# %%
Note : Python Programming is case sensitive programming language

# %%
Datatypes are classified into two types :

# %%
1. Mutable Datatypes ---> which will be to (edit/alter) flexible in nature

# %%
2. Immutable Datatypes ---> which will not be able to (edit/alter) fixed in nature

# %%
for instance :

# %%
#string ---> single quote

# %%
name1 = 'Ali'

# %%
print(name1)
# Out:
# Ali

# %%
#string ---> double quote

# %%
name2 = 'Hashim'

# %%
print(name2)
# Out:
# Hashim

# %%
NOTE : There is no difference between (single and double) quotes

# %%
Introduction to string methods :

# %%
type(name)
# Out:
# str

# %%
type(name2)
# Out:
# str

# %%
# is used for commenting the code

# %%
fullname = 'Ali akbar'

# %%
print(fullname)
# Out:
# Ali akbar

# %%
print(fullname.title())
# Out:
# Ali Akbar

# %%
# For changing the whole name in capital letters

# %%
print(fullname.upper())
# Out:
# ALI AKBAR

# %%
# For changing the whole name in small letters

# %%
print(fullname.lower())
# Out:
# ali akbar

# %%
Day 02 Completed
