# %%
Introduction to Number

# %%
num = 1

# %%
num = 2

# %%
type(num)
# Out:
# int

# %%
x = 0.1

# %%
print(x)
# Out:
# 0.1

# %%
Decimal values in python

# %%
type(x)
# Out:
# float

# %%
Introduction to list datatype

# %%
Definition : To list datatype ---> A list is a collection of items declared in s particular order

# %%
Classification : It's classified as Mutable Datatype

# %%
How do you define the list ---> [] ?

# %%
students = ['vicky','abdul','shree','anwar','murali'] # 0,1,2,3,4

# %%
print(students)
# Out:
# ['vicky', 'abdul', 'shree', 'anwar', 'murali']

# %%
Introduction to Indexing : [0,1,2,3,4,5........]

# %%
# how to access the elements in the list......?

# %%
# req : I want to access abdul name in the output

# %%
print(students[1])
# Out:
# abdul

# %%
print(students[1].title())
# Out:
# Abdul

# %%
How to add elements to the list?
How to modify elelments in the list?
How to delete the elements in the list?

# %%
print(students)
# Out:
# ['vicky', 'abdul', 'shree', 'anwar', 'murali']

# %%
# req : I want to add Varun in the list

# %%
students.append('varun')

# %%
print(students)
# Out:
# ['vicky', 'abdul', 'shree', 'anwar', 'murali', 'varun', 'varun']

# %%
# req : I want to add Praneeth

# %%
students.append('praneeth')

# %%
print(students)
# Out:
# ['vicky', 'abdul', 'shree', 'anwar', 'murali', 'varun', 'varun', 'praneeth']

# %%
# req : I want to add divya at 2nd Index

# %%
students.insert(2,'divya')

# %%
print(students)
# Out:
# ['vicky', 'abdul', 'divya', 'shree', 'anwar', 'murali', 'varun', 'varun', 'praneeth']

# %%
Note : Important Question ---> What is the difference between append method and insert methid in the last datatype....?

# %%
print(students)
# Out:
# ['vicky', 'abdul', 'divya', 'shree', 'anwar', 'murali', 'varun', 'varun', 'praneeth']

# %%
# req : I want to modify Divya to Dinesh

# %%
students[2] = 'dinesh'

# %%
print(students)
# Out:
# ['vicky', 'abdul', 'dinesh', 'shree', 'anwar', 'murali', 'varun', 'varun', 'praneeth']

# %%
# req : I want to delete Vicky from the above list

# %%
For deleting there are differences in approaches :

# %%
1. Temperory deleting ===== it will be storing a carbo copy of the deleted item to the variable assigned
   we will be using the method called pop()
   by defualt pop will be deleting the last element in the list
2. Permanent deleting

# %%
print(students)
# Out:
# ['vicky', 'abdul', 'dinesh', 'shree', 'anwar', 'murali', 'varun', 'varun', 'praneeth']

# %%
x = students.pop()

# %%
print(students)
# Out:
# ['vicky', 'abdul', 'dinesh', 'shree', 'anwar', 'murali', 'varun', 'varun']

# %%
print(x)
# Out:
# praneeth

# %%
a = students.pop(0)

# %%
print(students)
# Out:
# ['abdul', 'dinesh', 'shree', 'anwar', 'murali', 'varun', 'varun']

# %%
print(a)
# Out:
# vicky

# %%
# req : I want to delete Dinesh

# %%
del students[1]

# %%
print(students)
# Out:
# ['abdul', 'shree', 'anwar', 'murali', 'varun', 'varun']

# %%
Day 04 Completed
