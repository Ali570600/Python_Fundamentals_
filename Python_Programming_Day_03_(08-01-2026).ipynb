# %%
....continuation with string datatypes

# %%
Introduction to f strings

# %%
# general syntax of f strings

# %%
f "custom message, {place_holder-1} {place_holder-2} {place_holder-n}"

# %%
firstname = 'Ali'

# %%
lastname = 'Abbas'

# %%
# I want the name to be combined

# %%
fullname = f"{firstname} {lastname}"

# %%
print(fullname)
# Out:
# Ali Abbas

# %%
message = f"keep up for the good work, {fullname.title()}"

# %%
print(message)
# Out:
# keep up for the good work, Ali Abbas

# %%
Adding whitespaces to strings :

# %%
print("Favourite_Prog_lang:Pythonc++JavacswiftJavascript")
# Out:
# Favourite_Prog_lang:Pythonc++JavacswiftJavascript

# %%
print("Favourite_Prog_lang:\nPython\nc++\nJava\nc\nswift\nJava Script")
# Out:
# Favourite_Prog_lang:
# Python
# c++
# Java
# c
# swift
# Java Script

# %%
\n ---> new line delimiter

# %%
print("Favourite_Prog_lang:\n\tPython\n\tc++\n\tJava\n\tc\n\tswift\n\tJava Script")
# Out:
# Favourite_Prog_lang:
# 	Python
# 	c++
# 	Java
# 	c
# 	swift
# 	Java Script

# %%
\t ---> tab delimiter

# %%
Removing whitespaces from the strings

# %%
name = " python"

# %%
print(name)
# Out:
#  python

# %%
NOTE : In the above programming the word python is moved towards right side due to the whitespace
       In the below programming the word python is at the correct place

# %%
name2 = "python"

# %%
print(name2)
# Out:
# python

# %%
name.lstrip()
# Out:
# 'python'

# %%
name2.rstrip()
# Out:
# 'python'

# %%
name3 = " python"

# %%
print(name3)
# Out:
#  python

# %%
Zen of Python : ---> (is like a Rule book or Guidelines for a Python Programmer)

# %%
import this

# %%
The Zen of Python, by Tim Peters.
Beautiful is better than Ugly,
Explicit is better than Implicit,
Simple is better than Complex,
Complex is better than Complicated,
Flat is better than Nested,
Sparse is better than Dense,
Readability Counts,
Special cases aren't special enough to break the rules,
Although Practicality beats Purity,
Errors should never pass silently,
Unless Explicitly silenced,
In the face ambiguity refuse the temptation to guess,
There should be one ..... and preferably only one ..... obvious way to do to it,
Although that way may not be obvious at first unless you are Dutch
Now is better Never,
Altough never is *right* now,
If the implementation is hard to explain, it's a bad idea,
If the implementation is easy to explain, it may be a good idea,
